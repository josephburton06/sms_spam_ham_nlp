# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

import seaborn as sns

import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import sms_helpers
from sms_helpers import original_word_count
from sms_helpers import basic_clean
from sms_helpers import article_word_count
from sms_helpers import article_percent
from sms_helpers import text_prep
from sms_helpers import remove_stopwords

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_table('SMSSpamCollection.txt', header=None)
df.columns = ['result', 'original']

# %%
df.shape
# Out:
# (5572, 2)

# %%
df = text_prep(df)
df.head(3)
# Out:
#   result                                           original  original_cnt  \
# 0    ham  Go until jurong point, crazy.. Available only ...            20
# 1    ham                      Ok lar... Joking wif u oni...             6
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...            28
#
#                                              article  article_cnt  \
# 0  go until jurong point crazy available only in ...           20
# 1                            ok lar joking wif u oni            6
# 2  free entry in 2 a wkly comp to win fa cup fina...           33
#
#    article_per_kept                                              clean  \
# 0          1.000000  go jurong point crazy available bugis n great ...
# 1          1.000000                            ok lar joking wif u oni
# 2          1.178571  free entry 2 wkly comp win fa cup final tkts 2...
#
#    clean_cnt
# 0         16
# 1          6
# 2         25

# %%
df[df.article_cnt != df.clean_cnt]
# Out:
#      result                                           original  original_cnt  \
# 0       ham  Go until jurong point, crazy.. Available only ...            20
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...            28
# 3       ham  U dun say so early hor... U c already then say...            11
# 4       ham  Nah I don't think he goes to usf, he lives aro...            13
# 5      spam  FreeMsg Hey there darling it's been 3 week's n...            32
# 6       ham  Even my brother is not like to speak with me. ...            16
# 7       ham  As per your request 'Melle Melle (Oru Minnamin...            26
# 8      spam  WINNER!! As a valued network customer you have...            26
# 9      spam  Had your mobile 11 months or more? U R entitle...            29
# 10      ham  I'm gonna be home soon and i don't want to tal...            21
# 11     spam  SIX chances to win CASH! From 100 to 20,000 po...            26
# 12     spam  URGENT! You have won a 1 week FREE membership ...            26
# 13      ham  I've been searching for the right words to tha...            37
# 14      ham                I HAVE A DATE ON SUNDAY WITH WILL!!             8
# 15     spam  XXXMobileMovieClub: To use your credit, click ...            19
# 16      ham                         Oh k...i'm watching here:)             4
# 17      ham  Eh u remember how 2 spell his name... Yes i di...            19
# 18      ham  Fine if thats the way u feel. Thats the way ...            13
# 19     spam  England v Macedonia - dont miss the goals/team...            24
# 20      ham          Is that seriously how you spell his name?             8
# 21      ham    I‘m going to try for 2 months ha ha only joking            11
# 22      ham  So ü pay first lar... Then when is da stock co...            11
# 23      ham  Aft i finish my lunch then i go str down lor. ...            20
# 24      ham  Ffffffffff. Alright no way I can meet up with ...            11
# 25      ham  Just forced myself to eat a slice. I'm really ...            28
# 26      ham                     Lol your always so convincing.             5
# 27      ham  Did you catch the bus ? Are you frying an egg ...            32
# 28      ham  I'm back &amp; we're packing the car now, I'll...            15
# 29      ham  Ahhh. Work. I vaguely remember that! What does...            12
# 30      ham  Wait that's still not all that clear, were you...            26
# ...     ...                                                ...           ...
# 5541    ham                              Yeah it's jus rite...             4
# 5542    ham           Armand says get your ass over to epsilon             8
# 5543    ham             U still havent got urself a jacket ah?             8
# 5544    ham  I'm taking derek &amp; taylor to walmart, if I...            30
# 5545    ham      Hi its in durban are you still on this number            10
# 5546    ham         Ic. There are a lotta childporn cars then.             8
# 5547   spam  Had your contract mobile 11 Mnths? Latest Moto...            28
# 5548    ham                 No, I was trying it all weekend ;V             8
# 5549    ham  You know, wot people wear. T shirts, jumpers, ...            18
# 5550    ham        Cool, what time you think you can get here?             9
# 5551    ham  Wen did you get so spiritual and deep. That's ...            10
# 5552    ham  Have a safe trip to Nigeria. Wish you happines...            17
# 5553    ham                        Hahaha..use your brain dear             4
# 5554    ham  Well keep in mind I've only got enough gas for...            20
# 5555    ham  Yeh. Indians was nice. Tho it did kane me off ...            38
# 5556    ham  Yes i have. So that's why u texted. Pshew...mi...            12
# 5557    ham  No. I meant the calculation is the same. That ...            48
# 5558    ham                             Sorry, I'll call later             4
# 5559    ham  if you aren't here in the next  &lt;#&gt;  hou...            13
# 5560    ham                  Anything lor. Juz both of us lor.             7
# 5561    ham  Get me out of this dump heap. My mom decided t...            15
# 5562    ham  Ok lor... Sony ericsson salesman... I ask shuh...            18
# 5564    ham  Why don't you wait 'til at least wednesday to ...            15
# 5565    ham                                       Huh y lei...             3
# 5566   spam  REMINDER FROM O2: To get 2.50 pounds free call...            28
# 5567   spam  This is the 2nd time we have tried 2 contact u...            30
# 5568    ham               Will ü b going to esplanade fr home?             8
# 5569    ham  Pity, * was in mood for that. So...any other s...            10
# 5570    ham  The guy did some bitching but I acted like i'd...            26
# 5571    ham                         Rofl. Its true to its name             6
#
#                                                 article  article_cnt  \
# 0     go until jurong point crazy available only in ...           20
# 2     free entry in 2 a wkly comp to win fa cup fina...           33
# 3           u dun say so early hor u c already then say           11
# 4     nah i don t think he goes to usf he lives arou...           14
# 5     freemsg hey there darling it s been 3 week s n...           36
# 6     even my brother is not like to speak with me t...           16
# 7     as per your request melle melle oru minnaminun...           26
# 8     winner as a valued network customer you have b...           26
# 9     had your mobile 11 months or more u r entitled...           29
# 10    i m gonna be home soon and i don t want to tal...           24
# 11    six chances to win cash from 100 to 20 000 pou...           28
# 12    urgent you have won a 1 week free membership i...           30
# 13    i ve been searching for the right words to tha...           38
# 14                    i have a date on sunday with will            8
# 15    xxxmobilemovieclub to use your credit click th...           23
# 16                               oh k i m watching here            6
# 17    eh u remember how 2 spell his name yes i did h...           19
# 18    fine if thats the way u feel thats the way its...           13
# 19    england v macedonia dont miss the goals team n...           27
# 20             is that seriously how you spell his name            8
# 21       im going to try for 2 months ha ha only joking           11
# 22       so u pay first lar then when is da stock comin           11
# 23    aft i finish my lunch then i go str down lor a...           20
# 24    ffffffffff alright no way i can meet up with y...           11
# 25    just forced myself to eat a slice i m really n...           30
# 26                        lol your always so convincing            5
# 27    did you catch the bus are you frying an egg di...           29
# 28    i m back amp we re packing the car now i ll le...           19
# 29    ahhh work i vaguely remember that what does it...           12
# 30    wait that s still not all that clear were you ...           29
# ...                                                 ...          ...
# 5541                                 yeah it s jus rite            5
# 5542           armand says get your ass over to epsilon            8
# 5543              u still havent got urself a jacket ah            8
# 5544  i m taking derek amp taylor to walmart if i m ...           35
# 5545      hi its in durban are you still on this number           10
# 5546           ic there are a lotta childporn cars then            8
# 5547  had your contract mobile 11 mnths latest motor...           27
# 5548                   no i was trying it all weekend v            8
# 5549  you know wot people wear t shirts jumpers hat ...           18
# 5550          cool what time you think you can get here            9
# 5551  wen did you get so spiritual and deep that s g...           11
# 5552  have a safe trip to nigeria wish you happiness...           17
# 5553                         hahaha use your brain dear            5
# 5554  well keep in mind i ve only got enough gas for...           21
# 5555  yeh indians was nice tho it did kane me off a ...           38
# 5556  yes i have so that s why u texted pshew missin...           14
# 5557  no i meant the calculation is the same that lt...           50
# 5558                              sorry i ll call later            5
# 5559  if you aren t here in the next lt gt hours imm...           15
# 5560                    anything lor juz both of us lor            7
# 5561  get me out of this dump heap my mom decided to...           15
# 5562  ok lor sony ericsson salesman i ask shuhui the...           18
# 5564  why don t you wait til at least wednesday to s...           15
# 5565                                          huh y lei            3
# 5566  reminder from o2 to get 2 50 pounds free call ...           29
# 5567  this is the 2nd time we have tried 2 contact u...           32
# 5568                will u b going to esplanade fr home            8
# 5569  pity was in mood for that so any other suggest...           10
# 5570  the guy did some bitching but i acted like i d...           27
# 5571                          rofl its true to its name            6
#
#       article_per_kept                                              clean  \
# 0             1.000000  go jurong point crazy available bugis n great ...
# 2             1.178571  free entry 2 wkly comp win fa cup final tkts 2...
# 3             1.000000                u dun say early hor u c already say
# 4             1.076923             nah think goes usf lives around though
# 5             1.125000  freemsg hey darling 3 week word back like fun ...
# 6             1.000000     even brother like speak treat like aids patent
# 7             1.000000  per request melle melle oru minnaminunginte nu...
# 8             1.000000  winner valued network customer selected receiv...
# 9             1.000000  mobile 11 months u r entitled update latest co...
# 10            1.142857  gonna home soon want talk stuff anymore tonigh...
# 11            1.076923  six chances win cash 100 20 000 pounds txt csh...
# 12            1.153846  urgent 1 week free membership 100 000 prize ja...
# 13            1.027027  searching right words thank breather promise w...
# 14            1.000000                                        date sunday
# 15            1.210526  xxxmobilemovieclub use credit click wap link n...
# 16            1.500000                                      oh k watching
# 17            1.000000  eh u remember 2 spell name yes v naughty make ...
# 18            1.000000             fine thats way u feel thats way gota b
# 19            1.125000  england v macedonia dont miss goals team news ...
# 20            1.000000                               seriously spell name
# 21            1.000000                 im going try 2 months ha ha joking
# 22            1.000000                     u pay first lar da stock comin
# 23            1.000000  aft finish lunch go str lor ard 3 smth lor u f...
# 24            1.000000                 ffffffffff alright way meet sooner
# 25            1.071429  forced eat slice really hungry tho sucks mark ...
# 26            1.000000                              lol always convincing
# 27            0.906250  catch bus frying egg make tea eating mom left ...
# 28            1.266667                 back amp packing car let know room
# 29            1.000000           ahhh work vaguely remember feel like lol
# 30            1.115385     wait still clear sure sarcastic x want live us
# ...                ...                                                ...
# 5541          1.250000                                      yeah jus rite
# 5542          1.000000                        armand says get ass epsilon
# 5543          1.000000                u still havent got urself jacket ah
# 5544          1.166667  taking derek amp taylor walmart back time done...
# 5545          1.000000                             hi durban still number
# 5546          1.000000                            ic lotta childporn cars
# 5547          0.964286  contract mobile 11 mnths latest motorola nokia...
# 5548          1.000000                                   trying weekend v
# 5549          1.000000  know wot people wear shirts jumpers hat belt k...
# 5550          1.000000                                cool time think get
# 5551          1.100000                       wen get spiritual deep great
# 5552          1.000000  safe trip nigeria wish happiness soon company ...
# 5553          1.250000                              hahaha use brain dear
# 5554          1.050000  well keep mind got enough gas one round trip b...
# 5555          1.000000  yeh indians nice tho kane bit shud go 4 drink ...
# 5556          1.166667                    yes u texted pshew missing much
# 5557          1.041667  meant calculation lt gt units lt gt school rea...
# 5558          1.250000                                   sorry call later
# 5559          1.153846                    next lt gt hours imma flip shit
# 5560          1.000000                            anything lor juz us lor
# 5561          1.000000        get dump heap mom decided come lowes boring
# 5562          1.000000  ok lor sony ericsson salesman ask shuhui say q...
# 5564          1.000000                   wait til least wednesday see get
# 5565          1.000000                                            huh lei
# 5566          1.035714  reminder o2 get 2 50 pounds free call credit d...
# 5567          1.066667  2nd time tried 2 contact u u 750 pound prize 2...
# 5568          1.000000                        u b going esplanade fr home
# 5569          1.000000                              pity mood suggestions
# 5570          1.038462  guy bitching acted like interested buying some...
# 5571          1.000000                                     rofl true name
#
#       clean_cnt
# 0            16
# 2            25
# 3             9
# 4             7
# 5            19
# 6             8
# 7            16
# 8            18
# 9            18
# 10           12
# 11           23
# 12           20
# 13           15
# 14            2
# 15           16
# 16            3
# 17           12
# 18            9
# 19           24
# 20            3
# 21            8
# 22            7
# 23           15
# 24            5
# 25           15
# 26            3
# 27           12
# 28            7
# 29            7
# 30            9
# ...         ...
# 5541          3
# 5542          5
# 5543          7
# 5544         14
# 5545          4
# 5546          4
# 5547         19
# 5548          3
# 5549         11
# 5550          4
# 5551          5
# 5552          9
# 5553          4
# 5554         13
# 5555         26
# 5556          6
# 5557         20
# 5558          3
# 5559          7
# 5560          5
# 5561          8
# 5562         13
# 5564          6
# 5565          2
# 5566         20
# 5567         22
# 5568          6
# 5569          3
# 5570         13
# 5571          3
#
# [5365 rows x 8 columns]

# %%
df.groupby('result')[['article_per_kept']].agg(['mean', 'min', 'max'])
# Out:
#        article_per_kept
#                    mean       min  max
# result
# ham            1.044544  0.000000  8.0
# spam           1.074434  0.863636  3.0

# %%
df[df.article_per_kept > 3]
# Out:
#      result                                           original  original_cnt  \
# 3094    ham  staff.science.nus.edu.sg/~phyhcmk/teaching/pc1323             1
#
#                                                article  article_cnt  \
# 3094  staff science nus edu sg phyhcmk teaching pc1323            8
#
#       article_per_kept                                             clean  \
# 3094               8.0  staff science nus edu sg phyhcmk teaching pc1323
#
#       clean_cnt
# 3094          8

# %%
df[df.article_per_kept < .8]
# Out:
#      result                                           original  original_cnt  \
# 258     ham               Where are you lover ? I need you ...             9
# 826     ham         Hmm .. Bits and pieces lol ... *sighs* ...             9
# 960     ham                                            Where @             2
# 1139    ham                                  What * u wearing?             4
# 1147    ham                          Babe ? I lost you ... :-(             7
# 1591    ham  Somewhr someone is surely made 4 u. And God ha...            33
# 2062    ham  Hey ! I want you ! I crave you ! I miss you ! ...            26
# 2464    ham  Good afternoon, babe. How goes that day ? Any ...            22
# 2841    ham  BABE !!! I miiiiiiissssssssss you ! I need you...            29
# 3112    ham  Short But Cute : " Be a good person , but dont...            18
# 3342    ham                Still i have not checked it da. . .             9
# 3376    ham                                                :)              1
# 3450    ham                                Sorry. || mail? ||              4
# 3489    ham                Still i have not checked it da. . .             9
# 3668    ham  Honey ? Sweetheart ? Darling ? Sexy buns ? Sug...            30
# 3929    ham     Babe ? I lost you ... Will you try rebooting ?            11
# 4423    ham            MMM ... Fuck .... Merry Christmas to me             8
# 4487    ham                               have * good weekend.             4
# 4824    ham                                            :-) :-)             2
# 5022    ham                                :-( sad puppy noise             4
# 5287    ham  Hey ! Don't forget ... You are MINE ... For ME...            23
#
#                                                 article  article_cnt  \
# 258                      where are you lover i need you            7
# 826                       hmm bits and pieces lol sighs            6
# 960                                               where            1
# 1139                                     what u wearing            3
# 1147                                    babe i lost you            4
# 1591  somewhr someone is surely made 4 u and god has...           25
# 2062  hey i want you i crave you i miss you i need y...           20
# 2464  good afternoon babe how goes that day any job ...           17
# 2841  babe i miiiiiiissssssssss you i need you i cra...           21
# 3112  short but cute be a good person but dont try t...           14
# 3342                     still i have not checked it da            7
# 3376                                                               0
# 3450                                         sorry mail            2
# 3489                     still i have not checked it da            7
# 3668  honey sweetheart darling sexy buns sugar plum ...           22
# 3929             babe i lost you will you try rebooting            8
# 4423                     mmm fuck merry christmas to me            6
# 4487                                  have good weekend            3
# 4824                                                               0
# 5022                                    sad puppy noise            3
# 5287  hey don t forget you are mine for me my posses...           16
#
#       article_per_kept                                              clean  \
# 258           0.777778                                         lover need
# 826           0.666667                          hmm bits pieces lol sighs
# 960           0.500000
# 1139          0.750000                                          u wearing
# 1147          0.571429                                          babe lost
# 1591          0.757576  somewhr someone surely made 4 u god decided pe...
# 2062          0.769231  hey want crave miss need love ahmad saeed al h...
# 2464          0.772727  good afternoon babe goes day job prospects yet...
# 2841          0.724138  babe miiiiiiissssssssss need crave geeee sad w...
# 3112          0.777778     short cute good person dont try prove gud mrng
# 3342          0.777778                                   still checked da
# 3376          0.000000
# 3450          0.500000                                         sorry mail
# 3489          0.777778                                   still checked da
# 3668          0.733333  honey sweetheart darling sexy buns sugar plum ...
# 3929          0.727273                            babe lost try rebooting
# 4423          0.750000                           mmm fuck merry christmas
# 4487          0.750000                                       good weekend
# 4824          0.000000
# 5022          0.750000                                    sad puppy noise
# 5287          0.695652  hey forget mine possession property mmm childi...
#
#       clean_cnt
# 258           2
# 826           5
# 960           0
# 1139          2
# 1147          2
# 1591         20
# 2062         10
# 2464         11
# 2841          9
# 3112          9
# 3342          3
# 3376          0
# 3450          2
# 3489          3
# 3668         14
# 3929          4
# 4423          4
# 4487          2
# 4824          0
# 5022          3
# 5287          8

# %% [markdown]
# ### Looking at the three cells above, what can this mean?  Spam messages appear to not be just one long link or emoji/short responses.

# %%
df.groupby('result').count()
# Out:
#         original  original_cnt  article  article_cnt  article_per_kept  clean  \
# result
# ham         4825          4825     4825         4825              4825   4825
# spam         747           747      747          747               747    747
#
#         clean_cnt
# result
# ham          4825
# spam          747

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()

# %%
X = tfidf.fit_transform(df.clean)
y = df.result

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=.2)

train = pd.DataFrame(dict(actual=y_train))
test = pd.DataFrame(dict(actual=y_test))

lm = LogisticRegression().fit(X_train, y_train)

train['predicted'] = lm.predict(X_train)

print('Accuracy: {:.2%}'.format(accuracy_score(train.actual, train.predicted)))
print('---')
print('Confusion Matrix')
print(pd.crosstab(train.predicted, train.actual))
print('---')
print(classification_report(train.actual, train.predicted))
# Out:
# Accuracy: 97.02%
# ---
# Confusion Matrix
# actual      ham  spam
# predicted
# ham        3853   127
# spam          6   471
# ---
#               precision    recall  f1-score   support
#
#          ham       0.97      1.00      0.98      3859
#         spam       0.99      0.79      0.88       598
#
#    micro avg       0.97      0.97      0.97      4457
#    macro avg       0.98      0.89      0.93      4457
# weighted avg       0.97      0.97      0.97      4457

# %% [markdown]
# ### That's a pretty high accuracy on a large set.  Let's check on the test set now.

# %%
test['predicted'] = lm.predict(X_test)

print('Accuracy: {:.2%}'.format(accuracy_score(test.actual, test.predicted)))
print('---')
print('Confusion Matrix')
print(pd.crosstab(test.predicted, test.actual))
print('---')
print(classification_report(test.actual, test.predicted))
# Out:
# Accuracy: 96.32%
# ---
# Confusion Matrix
# actual     ham  spam
# predicted
# ham        965    40
# spam         1   109
# ---
#               precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98       966
#         spam       0.99      0.73      0.84       149
#
#    micro avg       0.96      0.96      0.96      1115
#    macro avg       0.98      0.87      0.91      1115
# weighted avg       0.96      0.96      0.96      1115
